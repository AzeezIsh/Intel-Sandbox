# %%
# import numpy as np
import array_api_strict as np
# import array_api_compat.numpy as np
def viterbi_np(obs, states, start_p, trans_p, emit_p):
    num_states = len(states)
    num_obs = len(obs)
    
    # Convert state indices to numbers if necessary
    state_map = {state: idx for idx, state in enumerate(states)}
    
    # Convert parameters to numpy arrays
    start_prob = np.asarray([start_p[state] for state in states])
    trans_prob = np.asarray([[trans_p[prev][curr] for curr in states] for prev in states])
    emit_prob = np.asarray([[emit_p[state][ob] for ob in obs] for state in states])
    
    # Initialize the Viterbi table
    V = np.zeros((num_states, num_obs))
    path = np.zeros((num_states, num_obs), dtype=np.int16)
    
    # Initial state probabilities
    V[:, 0] = start_prob * emit_prob[:, 0]
    
    # Dynamic programming
    for t in range(1, num_obs):
        for curr_state in range(num_states):
            # Max transition probability from any previous state
            trans_probs = V[:, t-1] * trans_prob[:, curr_state]
            # Highest transition probability
            best_prev_state = np.argmax(trans_probs)
            # Curr state max probability
            V[curr_state, t] = trans_probs[best_prev_state] * emit_prob[curr_state, t]
            # Store path to backtrack
            path[curr_state, t] = best_prev_state
    
    # Backtrack to find the optimal path
    optimal_path = np.zeros(num_obs, dtype=np.int16)
    # Backtrack from state with the highest probability
    optimal_path[-1] = np.argmax(V[:, -1])
    # Optimal for loop
    for t in range(num_obs-2, -1, -1):
        optimal_path[t] = path[optimal_path[t+1], t+1]
    
    # Indices back to state names if necessary
    optimal_path_states = [states[idx] for idx in optimal_path]
    
    return V, optimal_path_states

# %%
# States and Observations
states = ["LowPower", "HighPerformance"]
obs = ["Idle", "Moderate", "Intensive"]

# Starting Probabilities
start_p = {"LowPower": 0.7, "HighPerformance": 0.3}

# Transition Probabilities
trans_p = {
    "LowPower": {"LowPower": 0.8, "HighPerformance": 0.2},
    "HighPerformance": {"LowPower": 0.3, "HighPerformance": 0.7}
}

# Emission Probabilities
emit_p = {
    "LowPower": {"Idle": 0.6, "Moderate": 0.3, "Intensive": 0.1},
    "HighPerformance": {"Idle": 0.1, "Moderate": 0.4, "Intensive": 0.5}
}

# Now let's use the viterbi algorithm to decode the most likely states for a given sequence of observations
V, path = viterbi_np(obs, states, start_p, trans_p, emit_p)
print("Viterbi matrix:\n", V)
print("Optimal path through the states:", path)
# Out:
# Viterbi matrix:
#  [[0.42     0.1008   0.008064]
#  [0.03     0.0336   0.01176 ]]
# Optimal path through the states: ['LowPower', 'HighPerformance', 'HighPerformance']

# %%
states = ["IntelDominant", "NvidiaDominant"]
start_p = {"IntelDominant": 0.5, "NvidiaDominant": 0.5}
trans_p = {
    "IntelDominant": {"IntelDominant": 0.6, "NvidiaDominant": 0.4},
    "NvidiaDominant": {"IntelDominant": 0.4, "NvidiaDominant": 0.6}
}
emit_p = {
    "IntelDominant": {
        "AIandDeepLearning": 0.1, "HighPerformanceComputing": 0.25, "GraphicIntensive": 0.05,
        "DataAnalytics": 0.2, "VirtualReality": 0.1, "EnergyEfficientComputing": 0.15,
        "ScientificModeling": 0.2, "CryptocurrencyMining": 0.05
    },
    "NvidiaDominant": {
        "AIandDeepLearning": 0.25, "HighPerformanceComputing": 0.1, "GraphicIntensive": 0.25,
        "DataAnalytics": 0.05, "VirtualReality": 0.15, "EnergyEfficientComputing": 0.05,
        "ScientificModeling": 0.05, "CryptocurrencyMining": 0.2
    }
}
obs = ["DataAnalytics", "HighPerformanceComputing", "AIandDeepLearning", 
       "GraphicIntensive", "VirtualReality", "ScientificModeling", 
       "EnergyEfficientComputing", "CryptocurrencyMining"]
V, path = viterbi_np(obs, states, start_p, trans_p, emit_p)
print("Viterbi matrix:\n", V)
print("Optimal path through the states:", path)
# Out:
# Viterbi matrix:
#  [[1.0000e-01 1.5000e-02 9.0000e-04 3.0000e-05 9.0000e-06 1.6200e-06
#   1.4580e-07 4.3740e-09]
#  [2.5000e-02 4.0000e-03 1.5000e-03 2.2500e-04 2.0250e-05 6.0750e-07
#   3.2400e-08 1.1664e-08]]
# Optimal path through the states: ['IntelDominant', 'IntelDominant', 'NvidiaDominant', 'NvidiaDominant', 'NvidiaDominant', 'IntelDominant', 'IntelDominant', 'NvidiaDominant']

# %%
def viterbi_np_verbose(obs, states, start_p, trans_p, emit_p):
    num_states = len(states)
    num_obs = len(obs)
    
    state_map = {state: idx for idx, state in enumerate(states)}
    
    start_prob = np.asarray([start_p[state] for state in states])
    trans_prob = np.asarray([[trans_p[prev][curr] for curr in states] for prev in states])
    emit_prob = np.asarray([[emit_p[state][ob] for ob in obs] for state in states])
    
    V = np.zeros((num_states, num_obs))
    path = np.zeros((num_states, num_obs), dtype=np.int16)
    
    V[:, 0] = start_prob * emit_prob[:, 0]
    print(f"Initialization: {obs[0]}")
    for state in states:
        print(f"P({state}|{obs[0]}) = start_p[{state}] * emit_p[{state}][{obs[0]}] = {start_prob[state_map[state]]} * {emit_prob[state_map[state], 0]} = {V[state_map[state], 0]}")
    
    for t in range(1, num_obs):
        print(f"\nStep {t}: {obs[t]}")
        for curr_state in range(num_states):
            trans_probs = V[:, t-1] * trans_prob[:, curr_state]
            best_prev_state = np.argmax(trans_probs)
            V[curr_state, t] = trans_probs[best_prev_state] * emit_prob[curr_state, t]
            path[curr_state, t] = best_prev_state
            print(f"P({states[curr_state]}|{obs[t]}) = max(P(prev_state)*trans_p[prev_state][{states[curr_state]}])*emit_p[{states[curr_state]}][{obs[t]}]")
            for prev_state in range(num_states):
                print(f"  P({states[prev_state]})*trans_p[{states[prev_state]}][{states[curr_state]}] = {V[prev_state, t-1]} * {trans_prob[prev_state, curr_state]} = {V[prev_state, t-1] * trans_prob[prev_state, curr_state]}")
            print(f"Selected max: {trans_probs[best_prev_state]} * {emit_prob[curr_state, t]} = {V[curr_state, t]} from {states[best_prev_state]}")
    
    optimal_path = np.zeros(num_obs, dtype=np.int16)
    optimal_path[-1] = np.argmax(V[:, -1])
    for t in range(num_obs-2, -1, -1):
        optimal_path[t] = path[optimal_path[t+1], t+1]
    
    optimal_path_states = [states[idx] for idx in optimal_path]
    
    return V, optimal_path_states

V, path = viterbi_np_verbose(obs, states, start_p, trans_p, emit_p)
print("\nViterbi matrix:\n", V)
print("Optimal path through the states:", path)
# Out:
# Initialization: DataAnalytics
# P(IntelDominant|DataAnalytics) = start_p[IntelDominant] * emit_p[IntelDominant][DataAnalytics] = 0.5 * 0.2 = 0.1
# P(NvidiaDominant|DataAnalytics) = start_p[NvidiaDominant] * emit_p[NvidiaDominant][DataAnalytics] = 0.5 * 0.05 = 0.025
#
# Step 1: HighPerformanceComputing
# P(IntelDominant|HighPerformanceComputing) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][HighPerformanceComputing]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 0.1 * 0.6 = 0.06
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.025 * 0.4 = 0.010000000000000002
# Selected max: 0.06 * 0.25 = 0.015 from IntelDominant
# P(NvidiaDominant|HighPerformanceComputing) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][HighPerformanceComputing]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 0.1 * 0.4 = 0.04000000000000001
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.025 * 0.6 = 0.015
# Selected max: 0.04000000000000001 * 0.1 = 0.004000000000000001 from IntelDominant
#
# Step 2: AIandDeepLearning
# P(IntelDominant|AIandDeepLearning) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][AIandDeepLearning]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 0.015 * 0.6 = 0.009
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.004000000000000001 * 0.4 = 0.0016000000000000005
# Selected max: 0.009 * 0.1 = 0.0009 from IntelDominant
# P(NvidiaDominant|AIandDeepLearning) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][AIandDeepLearning]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 0.015 * 0.4 = 0.006
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.004000000000000001 * 0.6 = 0.0024000000000000007
# Selected max: 0.006 * 0.25 = 0.0015 from IntelDominant
#
# Step 3: GraphicIntensive
# P(IntelDominant|GraphicIntensive) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][GraphicIntensive]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 0.0009 * 0.6 = 0.00054
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.0015 * 0.4 = 0.0006000000000000001
# Selected max: 0.0006000000000000001 * 0.05 = 3.0000000000000004e-05 from NvidiaDominant
# P(NvidiaDominant|GraphicIntensive) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][GraphicIntensive]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 0.0009 * 0.4 = 0.00036
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.0015 * 0.6 = 0.0009
# Selected max: 0.0009 * 0.25 = 0.000225 from NvidiaDominant
#
# Step 4: VirtualReality
# P(IntelDominant|VirtualReality) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][VirtualReality]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 3.0000000000000004e-05 * 0.6 = 1.8e-05
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.000225 * 0.4 = 9e-05
# Selected max: 9e-05 * 0.1 = 9e-06 from NvidiaDominant
# P(NvidiaDominant|VirtualReality) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][VirtualReality]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 3.0000000000000004e-05 * 0.4 = 1.2000000000000002e-05
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.000225 * 0.6 = 0.000135
# Selected max: 0.000135 * 0.15 = 2.025e-05 from NvidiaDominant
#
# Step 5: ScientificModeling
# P(IntelDominant|ScientificModeling) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][ScientificModeling]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 9e-06 * 0.6 = 5.4e-06
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 2.025e-05 * 0.4 = 8.1e-06
# Selected max: 8.1e-06 * 0.2 = 1.6200000000000002e-06 from NvidiaDominant
# P(NvidiaDominant|ScientificModeling) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][ScientificModeling]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 9e-06 * 0.4 = 3.6000000000000003e-06
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 2.025e-05 * 0.6 = 1.215e-05
# Selected max: 1.215e-05 * 0.05 = 6.075000000000001e-07 from NvidiaDominant
#
# Step 6: EnergyEfficientComputing
# P(IntelDominant|EnergyEfficientComputing) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][EnergyEfficientComputing]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 1.6200000000000002e-06 * 0.6 = 9.72e-07
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 6.075000000000001e-07 * 0.4 = 2.4300000000000005e-07
# Selected max: 9.72e-07 * 0.15 = 1.458e-07 from IntelDominant
# P(NvidiaDominant|EnergyEfficientComputing) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][EnergyEfficientComputing]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 1.6200000000000002e-06 * 0.4 = 6.480000000000001e-07
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 6.075000000000001e-07 * 0.6 = 3.6450000000000007e-07
# Selected max: 6.480000000000001e-07 * 0.05 = 3.2400000000000006e-08 from IntelDominant
#
# Step 7: CryptocurrencyMining
# P(IntelDominant|CryptocurrencyMining) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][CryptocurrencyMining]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 1.458e-07 * 0.6 = 8.748e-08
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 3.2400000000000006e-08 * 0.4 = 1.2960000000000003e-08
# Selected max: 8.748e-08 * 0.05 = 4.374e-09 from IntelDominant
# P(NvidiaDominant|CryptocurrencyMining) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][CryptocurrencyMining]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 1.458e-07 * 0.4 = 5.832e-08
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 3.2400000000000006e-08 * 0.6 = 1.9440000000000004e-08
# Selected max: 5.832e-08 * 0.2 = 1.1664000000000001e-08 from IntelDominant
#
# Viterbi matrix:
#  [[1.0000e-01 1.5000e-02 9.0000e-04 3.0000e-05 9.0000e-06 1.6200e-06
#   1.4580e-07 4.3740e-09]
#  [2.5000e-02 4.0000e-03 1.5000e-03 2.2500e-04 2.0250e-05 6.0750e-07
#   3.2400e-08 1.1664e-08]]
# Optimal path through the states: ['IntelDominant', 'IntelDominant', 'NvidiaDominant', 'NvidiaDominant', 'NvidiaDominant', 'IntelDominant', 'IntelDominant', 'NvidiaDominant']

# %%
states = ["IntelDominant", "NvidiaDominant"]
start_p = {"IntelDominant": 0.5, "NvidiaDominant": 0.5}
trans_p = {
    "IntelDominant": {"IntelDominant": 0.6, "NvidiaDominant": 0.4},
    "NvidiaDominant": {"IntelDominant": 0.4, "NvidiaDominant": 0.6}
}
emit_p = {
    "IntelDominant": {
        "AIandDeepLearning": 0.1, "HighPerformanceComputing": 0.25, "GraphicIntensive": 0.05,
        "DataAnalytics": 0.2, "VirtualReality": 0.1, "EnergyEfficientComputing": 0.15,
        "ScientificModeling": 0.2, "CryptocurrencyMining": 0.05
    },
    "NvidiaDominant": {
        "AIandDeepLearning": 0.25, "HighPerformanceComputing": 0.1, "GraphicIntensive": 0.25,
        "DataAnalytics": 0.05, "VirtualReality": 0.15, "EnergyEfficientComputing": 0.05,
        "ScientificModeling": 0.05, "CryptocurrencyMining": 0.2
    }
}
obs = ["DataAnalytics", "HighPerformanceComputing", "AIandDeepLearning", 
       "GraphicIntensive", "VirtualReality", "ScientificModeling", 
       "EnergyEfficientComputing", "CryptocurrencyMining"]
V, path = viterbi_np_verbose(obs, states, start_p, trans_p, emit_p)
print("Viterbi matrix:\n", V)
print("Optimal path through the states:", path)
# Out:
# Initialization: DataAnalytics
# P(IntelDominant|DataAnalytics) = start_p[IntelDominant] * emit_p[IntelDominant][DataAnalytics] = 0.5 * 0.2 = 0.1
# P(NvidiaDominant|DataAnalytics) = start_p[NvidiaDominant] * emit_p[NvidiaDominant][DataAnalytics] = 0.5 * 0.05 = 0.025
#
# Step 1: HighPerformanceComputing
# P(IntelDominant|HighPerformanceComputing) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][HighPerformanceComputing]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 0.1 * 0.6 = 0.06
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.025 * 0.4 = 0.010000000000000002
# Selected max: 0.06 * 0.25 = 0.015 from IntelDominant
# P(NvidiaDominant|HighPerformanceComputing) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][HighPerformanceComputing]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 0.1 * 0.4 = 0.04000000000000001
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.025 * 0.6 = 0.015
# Selected max: 0.04000000000000001 * 0.1 = 0.004000000000000001 from IntelDominant
#
# Step 2: AIandDeepLearning
# P(IntelDominant|AIandDeepLearning) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][AIandDeepLearning]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 0.015 * 0.6 = 0.009
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.004000000000000001 * 0.4 = 0.0016000000000000005
# Selected max: 0.009 * 0.1 = 0.0009 from IntelDominant
# P(NvidiaDominant|AIandDeepLearning) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][AIandDeepLearning]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 0.015 * 0.4 = 0.006
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.004000000000000001 * 0.6 = 0.0024000000000000007
# Selected max: 0.006 * 0.25 = 0.0015 from IntelDominant
#
# Step 3: GraphicIntensive
# P(IntelDominant|GraphicIntensive) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][GraphicIntensive]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 0.0009 * 0.6 = 0.00054
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.0015 * 0.4 = 0.0006000000000000001
# Selected max: 0.0006000000000000001 * 0.05 = 3.0000000000000004e-05 from NvidiaDominant
# P(NvidiaDominant|GraphicIntensive) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][GraphicIntensive]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 0.0009 * 0.4 = 0.00036
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.0015 * 0.6 = 0.0009
# Selected max: 0.0009 * 0.25 = 0.000225 from NvidiaDominant
#
# Step 4: VirtualReality
# P(IntelDominant|VirtualReality) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][VirtualReality]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 3.0000000000000004e-05 * 0.6 = 1.8e-05
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 0.000225 * 0.4 = 9e-05
# Selected max: 9e-05 * 0.1 = 9e-06 from NvidiaDominant
# P(NvidiaDominant|VirtualReality) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][VirtualReality]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 3.0000000000000004e-05 * 0.4 = 1.2000000000000002e-05
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 0.000225 * 0.6 = 0.000135
# Selected max: 0.000135 * 0.15 = 2.025e-05 from NvidiaDominant
#
# Step 5: ScientificModeling
# P(IntelDominant|ScientificModeling) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][ScientificModeling]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 9e-06 * 0.6 = 5.4e-06
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 2.025e-05 * 0.4 = 8.1e-06
# Selected max: 8.1e-06 * 0.2 = 1.6200000000000002e-06 from NvidiaDominant
# P(NvidiaDominant|ScientificModeling) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][ScientificModeling]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 9e-06 * 0.4 = 3.6000000000000003e-06
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 2.025e-05 * 0.6 = 1.215e-05
# Selected max: 1.215e-05 * 0.05 = 6.075000000000001e-07 from NvidiaDominant
#
# Step 6: EnergyEfficientComputing
# P(IntelDominant|EnergyEfficientComputing) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][EnergyEfficientComputing]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 1.6200000000000002e-06 * 0.6 = 9.72e-07
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 6.075000000000001e-07 * 0.4 = 2.4300000000000005e-07
# Selected max: 9.72e-07 * 0.15 = 1.458e-07 from IntelDominant
# P(NvidiaDominant|EnergyEfficientComputing) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][EnergyEfficientComputing]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 1.6200000000000002e-06 * 0.4 = 6.480000000000001e-07
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 6.075000000000001e-07 * 0.6 = 3.6450000000000007e-07
# Selected max: 6.480000000000001e-07 * 0.05 = 3.2400000000000006e-08 from IntelDominant
#
# Step 7: CryptocurrencyMining
# P(IntelDominant|CryptocurrencyMining) = max(P(prev_state)*trans_p[prev_state][IntelDominant])*emit_p[IntelDominant][CryptocurrencyMining]
#   P(IntelDominant)*trans_p[IntelDominant][IntelDominant] = 1.458e-07 * 0.6 = 8.748e-08
#   P(NvidiaDominant)*trans_p[NvidiaDominant][IntelDominant] = 3.2400000000000006e-08 * 0.4 = 1.2960000000000003e-08
# Selected max: 8.748e-08 * 0.05 = 4.374e-09 from IntelDominant
# P(NvidiaDominant|CryptocurrencyMining) = max(P(prev_state)*trans_p[prev_state][NvidiaDominant])*emit_p[NvidiaDominant][CryptocurrencyMining]
#   P(IntelDominant)*trans_p[IntelDominant][NvidiaDominant] = 1.458e-07 * 0.4 = 5.832e-08
#   P(NvidiaDominant)*trans_p[NvidiaDominant][NvidiaDominant] = 3.2400000000000006e-08 * 0.6 = 1.9440000000000004e-08
# Selected max: 5.832e-08 * 0.2 = 1.1664000000000001e-08 from IntelDominant
# Viterbi matrix:
#  [[1.0000e-01 1.5000e-02 9.0000e-04 3.0000e-05 9.0000e-06 1.6200e-06
#   1.4580e-07 4.3740e-09]
#  [2.5000e-02 4.0000e-03 1.5000e-03 2.2500e-04 2.0250e-05 6.0750e-07
#   3.2400e-08 1.1664e-08]]
# Optimal path through the states: ['IntelDominant', 'IntelDominant', 'NvidiaDominant', 'NvidiaDominant', 'NvidiaDominant', 'IntelDominant', 'IntelDominant', 'NvidiaDominant']
